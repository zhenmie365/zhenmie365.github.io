# %% [markdown]
# # My first notebook

# %% [markdown]
# ## import packege

# %%
from IPython.display import Image
# %matplotlib inline

# %% [markdown]
# ### display image

# %%
Image(filename='./img/ensamble_model.png', width=500)

# %% [markdown]
# ### code model

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(20)
y = x ** 2

plt.plot(x, y)
